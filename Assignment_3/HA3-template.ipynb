# %% [markdown]
# ### Social Networks
#
# ### RWTH Aachen, Summer Semester 2017-2018
#
#
# # Home Assignment 3

# %%
#Libraries
import networkx as nx

import numpy as np
np.seterr(divide='ignore', invalid='ignore') # supressing some warnings - only do this is you know what you are doing
from numpy import genfromtxt
import powerlaw
print(powerlaw.__version__)
from pprint import pprint # pretty print

#plotting stuff
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# Out:
# 1.4.3

# %% [markdown]
# ## 1 Creation of networks

# %% [markdown]
# ## 1.1	G(n,m) with n=50, m=100

# %%
n=50
m=100
G = nx.gnm_random_graph(50, 100)
nx.draw(G, node_size = 100)
plt.show()

# %% [markdown]
# ### Average degree of the ensemble

# %% [markdown]
# ### Average geodesic distance of the ensemble

# %% [markdown]
# ### The expected theoretical value of the average degree of the ensemble

# %% [markdown]
# ## 1.2	G(n,p) with n=50, p=0.3

# %%
n = 50
p = 0.3
G = nx.gnp_random_graph(50, 0.3);
nx.draw(G, node_size = 100)
plt.show()

# %% [markdown]
# ### Average degree of the ensemble

# %%
C = nx.degree_centrality(G)
nodes =nx.number_of_nodes(G)
[v + a for a in C.values()]
v/nodes
# Out:
# 0.0

# %% [markdown]
# ### Average geodesic distance of the ensemble

# %% [markdown]
# ### The expected theoretical value of the average degree of the ensemble

# %% [markdown]
# ## 1.3 B.A. n=50, m=1

# %%
n = 50 
m =1
G = nx.barabasi_albert_graph(n,m)
nx.draw(G, node_size = 100)
plt.show()

# %% [markdown]
# ### Average degree of the ensemble

# %% [markdown]
# ### Average geodesic distance of the ensemble

# %% [markdown]
# ### The expected theoretical value of the average degree of the ensemble

# %% [markdown]
# ## 2. Power law data

# %% [markdown]
# ## 2.1 Degree distribution of synthetic network Ha3net

# %% [markdown]
# ### Linear binning

# %% [markdown]
# ### Logarithmic binning

# %% [markdown]
# ### Estimate the exponent alpha and lower bound xmin

# %% [markdown]
# ### Plot the pdf (probability distribution function, in this case the degree distribution) fit together with the data in a log-log plot. Use two different colours, one for the fit and one for the data.

# %% [markdown]
# ### Check the goodness of fit

# %% [markdown]
# ### Can you reject the hypothesis that the data comes from a power-law distribution?

# %% [markdown]
# ## 2.2 Degree distribution of the Astro Physics collaboration network

# %% [markdown]
# ### Linear binning

# %% [markdown]
# ### Logarithmic binning

# %% [markdown]
# ### Estimate the exponent alpha and lower bound xmin

# %% [markdown]
# ### Plot the pdf (probability distribution function, in this case the degree distribution) fit together with the data in a log-log plot. Use two different colours, one for the fit and one for the data.

# %% [markdown]
# ### Check the goodness of fit

# %% [markdown]
# ### Can you reject the hypothesis that the data comes from a power-law distribution?
